# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
torch.manual_seed(1)
os.environ['KMP_DUPLICATE_LIB_OK'] ='True'

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples
    train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.Resize((32, 32)),
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=train_batch_size, shuffle=True)

    # Fetch test data: total 10000 samples
    test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('data', train=False, transform=transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])),
        batch_size=test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()

        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5)
        self.conv2 = nn.Conv2d(32, 32, 5)
        self.conv3 = nn.Conv2d(32, 64, 5)
        self.fc1 = nn.Linear(1024, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv3(x),2))
        x = F.dropout(x, p=0.5, training=self.training)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
train_batch_size = 64
test_batch_size = 1000
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def train(model, optimizer, epoch, train_loader, log_interval):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    n_correct = 0
    train_loss = 0
    counter = 0
    n_samples = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        counter += 1
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.data

        pred = np.argmax(output.data, axis=1)
        n_samples += target.size(0)
        n_correct += (pred == target).sum().item()
        acc = 100.0 * n_correct / n_samples

        # print log
        if batch_idx % log_interval == 0:
            print('Train set, Epoch {} [{}/{}]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                loss.data))
            print("Train Accuracy: ", round(acc,2))
    train_loss /= counter
    return train_loss, round(acc,2)

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    loss_fn = torch.nn.CrossEntropyLoss(size_average=False)

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)

        output = model(data)
        test_loss += loss_fn(output, target).data

        pred = np.argmax(output.data, axis=1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss /= len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
torch.manual_seed(1)
model= LeNet()

lr = 0.01
momentum = 0.5
optimizer = optim.SGD(model.parameters(), lr, momentum)
m0_loss_arr = []
m0_acc_arr = []

epochs = 10
log_interval = 200
for epoch in range(1, epochs + 1):
    loss, acc = train(model, optimizer, epoch, train_loader, log_interval)
    m0_loss_arr.append(loss)
    m0_acc_arr.append(acc)
    test(model, epoch, test_loader)

# %%
torch.manual_seed(1)

model_1= CNN()

lr = 0.01
momentum = 0.5
optimizer = optim.SGD(model_1.parameters(), lr=lr, momentum=momentum)
m1_loss_arr = []
m1_acc_arr = []

epochs = 10
log_interval = 100
for epoch in range(1, epochs + 1):
    loss, acc = train(model_1, optimizer, epoch, train_loader, log_interval=log_interval)
    m1_loss_arr.append(loss)
    m1_acc_arr.append(acc)
    test(model_1, epoch, test_loader)
# Out:
# Train set, Epoch 1 [0/60000]	Loss: 2.315159
# Train Accuracy:  6.25
# Train set, Epoch 1 [6400/60000]	Loss: 1.539504
# Train Accuracy:  24.66
# Train set, Epoch 1 [12800/60000]	Loss: 0.930773
# Train Accuracy:  45.8
# Train set, Epoch 1 [19200/60000]	Loss: 0.390023
# Train Accuracy:  57.44
# Train set, Epoch 1 [25600/60000]	Loss: 0.409503
# Train Accuracy:  64.53
# Train set, Epoch 1 [32000/60000]	Loss: 0.283879
# Train Accuracy:  69.0
# Train set, Epoch 1 [38400/60000]	Loss: 0.380537
# Train Accuracy:  72.34
# Train set, Epoch 1 [44800/60000]	Loss: 0.312206
# Train Accuracy:  74.96
# Train set, Epoch 1 [51200/60000]	Loss: 0.283182
# Train Accuracy:  76.98
# Train set, Epoch 1 [57600/60000]	Loss: 0.463990
# Train Accuracy:  78.64
#
# Test set, Epoch 1 , Average loss: 0.1207, Accuracy: 9630/10000 (96%)
#
# Train set, Epoch 2 [0/60000]	Loss: 0.277765
# Train Accuracy:  95.31
# Train set, Epoch 2 [6400/60000]	Loss: 0.213677
# Train Accuracy:  93.12
# Train set, Epoch 2 [12800/60000]	Loss: 0.156652
# Train Accuracy:  93.24
# Train set, Epoch 2 [19200/60000]	Loss: 0.183918
# Train Accuracy:  93.28
# Train set, Epoch 2 [25600/60000]	Loss: 0.163482
# Train Accuracy:  93.48
# Train set, Epoch 2 [32000/60000]	Loss: 0.156299
# Train Accuracy:  93.65
# Train set, Epoch 2 [38400/60000]	Loss: 0.318920
# Train Accuracy:  93.77
# Train set, Epoch 2 [44800/60000]	Loss: 0.304383
# Train Accuracy:  93.86
# Train set, Epoch 2 [51200/60000]	Loss: 0.170233
# Train Accuracy:  93.96
# Train set, Epoch 2 [57600/60000]	Loss: 0.100753
# Train Accuracy:  94.11
#
# Test set, Epoch 2 , Average loss: 0.0727, Accuracy: 9775/10000 (98%)
#
# Train set, Epoch 3 [0/60000]	Loss: 0.091855
# Train Accuracy:  96.88
# Train set, Epoch 3 [6400/60000]	Loss: 0.185143
# Train Accuracy:  95.05
# Train set, Epoch 3 [12800/60000]	Loss: 0.137459
# Train Accuracy:  95.21
# Train set, Epoch 3 [19200/60000]	Loss: 0.240255
# Train Accuracy:  95.25
# Train set, Epoch 3 [25600/60000]	Loss: 0.074532
# Train Accuracy:  95.33
# Train set, Epoch 3 [32000/60000]	Loss: 0.144461
# Train Accuracy:  95.35
# Train set, Epoch 3 [38400/60000]	Loss: 0.105359
# Train Accuracy:  95.35
# Train set, Epoch 3 [44800/60000]	Loss: 0.304161
# Train Accuracy:  95.48
# Train set, Epoch 3 [51200/60000]	Loss: 0.071514
# Train Accuracy:  95.57
# Train set, Epoch 3 [57600/60000]	Loss: 0.255889
# Train Accuracy:  95.64
#
# Test set, Epoch 3 , Average loss: 0.0526, Accuracy: 9848/10000 (98%)
#
# Train set, Epoch 4 [0/60000]	Loss: 0.027161
# Train Accuracy:  100.0
# Train set, Epoch 4 [6400/60000]	Loss: 0.127922
# Train Accuracy:  96.02
# Train set, Epoch 4 [12800/60000]	Loss: 0.296115
# Train Accuracy:  96.22
# Train set, Epoch 4 [19200/60000]	Loss: 0.046547
# Train Accuracy:  96.32
# Train set, Epoch 4 [25600/60000]	Loss: 0.070409
# Train Accuracy:  96.29
# Train set, Epoch 4 [32000/60000]	Loss: 0.182821
# Train Accuracy:  96.34
# Train set, Epoch 4 [38400/60000]	Loss: 0.097219
# Train Accuracy:  96.32
# Train set, Epoch 4 [44800/60000]	Loss: 0.261453
# Train Accuracy:  96.35
# Train set, Epoch 4 [51200/60000]	Loss: 0.211843
# Train Accuracy:  96.42
# Train set, Epoch 4 [57600/60000]	Loss: 0.256815
# Train Accuracy:  96.47
#
# Test set, Epoch 4 , Average loss: 0.0435, Accuracy: 9868/10000 (99%)
#
# Train set, Epoch 5 [0/60000]	Loss: 0.113245
# Train Accuracy:  96.88
# Train set, Epoch 5 [6400/60000]	Loss: 0.045473
# Train Accuracy:  96.94
# Train set, Epoch 5 [12800/60000]	Loss: 0.096880
# Train Accuracy:  97.1
# Train set, Epoch 5 [19200/60000]	Loss: 0.071519
# Train Accuracy:  97.09
# Train set, Epoch 5 [25600/60000]	Loss: 0.010766
# Train Accuracy:  97.06
# Train set, Epoch 5 [32000/60000]	Loss: 0.009828
# Train Accuracy:  96.97
# Train set, Epoch 5 [38400/60000]	Loss: 0.041856
# Train Accuracy:  96.98
# Train set, Epoch 5 [44800/60000]	Loss: 0.143773
# Train Accuracy:  97.0
# Train set, Epoch 5 [51200/60000]	Loss: 0.102150
# Train Accuracy:  97.03
# Train set, Epoch 5 [57600/60000]	Loss: 0.081677
# Train Accuracy:  97.06
#
# Test set, Epoch 5 , Average loss: 0.0398, Accuracy: 9884/10000 (99%)
#
# Train set, Epoch 6 [0/60000]	Loss: 0.156708
# Train Accuracy:  95.31
# Train set, Epoch 6 [6400/60000]	Loss: 0.069291
# Train Accuracy:  97.23
# Train set, Epoch 6 [12800/60000]	Loss: 0.191918
# Train Accuracy:  97.07
# Train set, Epoch 6 [19200/60000]	Loss: 0.043684
# Train Accuracy:  97.11
# Train set, Epoch 6 [25600/60000]	Loss: 0.136916
# Train Accuracy:  97.12
# Train set, Epoch 6 [32000/60000]	Loss: 0.045957
# Train Accuracy:  97.12
# Train set, Epoch 6 [38400/60000]	Loss: 0.049551
# Train Accuracy:  97.22
# Train set, Epoch 6 [44800/60000]	Loss: 0.158135
# Train Accuracy:  97.27
# Train set, Epoch 6 [51200/60000]	Loss: 0.109491
# Train Accuracy:  97.29
# Train set, Epoch 6 [57600/60000]	Loss: 0.095725
# Train Accuracy:  97.29
#
# Test set, Epoch 6 , Average loss: 0.0362, Accuracy: 9892/10000 (99%)
#
# Train set, Epoch 7 [0/60000]	Loss: 0.078780
# Train Accuracy:  96.88
# Train set, Epoch 7 [6400/60000]	Loss: 0.079601
# Train Accuracy:  97.66
# Train set, Epoch 7 [12800/60000]	Loss: 0.110488
# Train Accuracy:  97.55
# Train set, Epoch 7 [19200/60000]	Loss: 0.062946
# Train Accuracy:  97.53
# Train set, Epoch 7 [25600/60000]	Loss: 0.097057
# Train Accuracy:  97.63
# Train set, Epoch 7 [32000/60000]	Loss: 0.194418
# Train Accuracy:  97.62
# Train set, Epoch 7 [38400/60000]	Loss: 0.013608
# Train Accuracy:  97.59
# Train set, Epoch 7 [44800/60000]	Loss: 0.008464
# Train Accuracy:  97.59
# Train set, Epoch 7 [51200/60000]	Loss: 0.072351
# Train Accuracy:  97.59
# Train set, Epoch 7 [57600/60000]	Loss: 0.137849
# Train Accuracy:  97.6
#
# Test set, Epoch 7 , Average loss: 0.0315, Accuracy: 9900/10000 (99%)
#
# Train set, Epoch 8 [0/60000]	Loss: 0.137004
# Train Accuracy:  95.31
# Train set, Epoch 8 [6400/60000]	Loss: 0.116305
# Train Accuracy:  97.74
# Train set, Epoch 8 [12800/60000]	Loss: 0.134010
# Train Accuracy:  97.81
# Train set, Epoch 8 [19200/60000]	Loss: 0.015659
# Train Accuracy:  97.78
# Train set, Epoch 8 [25600/60000]	Loss: 0.053213
# Train Accuracy:  97.72
# Train set, Epoch 8 [32000/60000]	Loss: 0.059291
# Train Accuracy:  97.7
# Train set, Epoch 8 [38400/60000]	Loss: 0.001916
# Train Accuracy:  97.74
# Train set, Epoch 8 [44800/60000]	Loss: 0.038524
# Train Accuracy:  97.77
# Train set, Epoch 8 [51200/60000]	Loss: 0.042647
# Train Accuracy:  97.77
# Train set, Epoch 8 [57600/60000]	Loss: 0.097823
# Train Accuracy:  97.81
#
# Test set, Epoch 8 , Average loss: 0.0286, Accuracy: 9913/10000 (99%)
#
# Train set, Epoch 9 [0/60000]	Loss: 0.032037
# Train Accuracy:  98.44
# Train set, Epoch 9 [6400/60000]	Loss: 0.149251
# Train Accuracy:  97.69
# Train set, Epoch 9 [12800/60000]	Loss: 0.078032
# Train Accuracy:  97.78
# Train set, Epoch 9 [19200/60000]	Loss: 0.084223
# Train Accuracy:  97.74
# Train set, Epoch 9 [25600/60000]	Loss: 0.053226
# Train Accuracy:  97.82
# Train set, Epoch 9 [32000/60000]	Loss: 0.013651
# Train Accuracy:  97.87
# Train set, Epoch 9 [38400/60000]	Loss: 0.028275
# Train Accuracy:  97.83
# Train set, Epoch 9 [44800/60000]	Loss: 0.125744
# Train Accuracy:  97.84
# Train set, Epoch 9 [51200/60000]	Loss: 0.020986
# Train Accuracy:  97.85
# Train set, Epoch 9 [57600/60000]	Loss: 0.095311
# Train Accuracy:  97.87
#
# Test set, Epoch 9 , Average loss: 0.0261, Accuracy: 9926/10000 (99%)
#
# Train set, Epoch 10 [0/60000]	Loss: 0.060996
# Train Accuracy:  98.44
# Train set, Epoch 10 [6400/60000]	Loss: 0.015944
# Train Accuracy:  97.59
# Train set, Epoch 10 [12800/60000]	Loss: 0.019987
# Train Accuracy:  97.88
# Train set, Epoch 10 [19200/60000]	Loss: 0.014968
# Train Accuracy:  97.97
# Train set, Epoch 10 [25600/60000]	Loss: 0.174892
# Train Accuracy:  97.94
# Train set, Epoch 10 [32000/60000]	Loss: 0.044932
# Train Accuracy:  97.94
# Train set, Epoch 10 [38400/60000]	Loss: 0.098425
# Train Accuracy:  97.95
# Train set, Epoch 10 [44800/60000]	Loss: 0.038673
# Train Accuracy:  97.97
# Train set, Epoch 10 [51200/60000]	Loss: 0.131539
# Train Accuracy:  97.97
# Train set, Epoch 10 [57600/60000]	Loss: 0.110794
# Train Accuracy:  97.95
#
# Test set, Epoch 10 , Average loss: 0.0246, Accuracy: 9927/10000 (99%)

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(1, 11, 1), m0_loss_arr, color = "r")
plt.plot(np.arange(1, 11, 1), m1_loss_arr, color = "g")
plt.title('Model Loss')
plt.legend(['Model 1', 'Model 2'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(1, 11, 1), m0_acc_arr, color = "r")
plt.plot(np.arange(1, 11, 1), m1_acc_arr, color = "g")
plt.title('Model Accuracy')
plt.legend(['Model 1', 'Model 2'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
