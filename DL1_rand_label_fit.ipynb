# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
torch.manual_seed(1)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples

    trainset = datasets.MNIST('data', train = True, download = False,
                transform = transforms.Compose([
                transforms.Resize((32,32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    trainset.targets = temp
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST('data', train = False,
                transform = transforms.Compose([
                transforms.Resize((32, 32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    test_loader = torch.utils.data.DataLoader(testset ,batch_size = test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def train(model, optimizer, train_loader):
    model.train()
    correct = 0
    train_loss = 0
    counter = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        counter += 1
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.data

        pred = np.argmax(output.data, axis=1)
        correct += np.equal(pred, target.data).sum()

    train_loss = (train_loss * 100) / len(train_loader.dataset)
    acc = 100.0 * correct / len(train_loader.dataset)
    return train_loss, acc

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)

        output = model(data)
        loss = loss_fn(output, target)
        test_loss += loss.data

        pred = np.argmax(output.data, axis = 1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss = (test_loss * 100) / len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss

# %%
model = CNN()

optimizer = optim.Adam(model.parameters(), lr=0.0001)
m1_train_loss_arr = []
m1_test_loss_arr = []

epochs = 100
log_interval = 500
loss_fn = torch.nn.CrossEntropyLoss()
for epoch in range(1, epochs + 1):
    tr_loss, acc = train(model, optimizer, train_loader)
    m1_train_loss_arr.append(tr_loss)
    loss_test = test(model, epoch, test_loader)
    m1_test_loss_arr.append(loss_test)
    print('Epoch: ', epoch)
    print('Loss= ', tr_loss)
# Out:
# Test set, Epoch 1 , Average loss: 2.3026, Accuracy: 616/10000 (6%)
#
# Epoch:  1
# Loss=  tensor(2.3033)
#
# Test set, Epoch 2 , Average loss: 2.2984, Accuracy: 1593/10000 (16%)
#
# Epoch:  2
# Loss=  tensor(2.3025)
#
# Test set, Epoch 3 , Average loss: 2.2983, Accuracy: 1305/10000 (13%)
#
# Epoch:  3
# Loss=  tensor(2.3021)
#
# Test set, Epoch 4 , Average loss: 2.2995, Accuracy: 744/10000 (7%)
#
# Epoch:  4
# Loss=  tensor(2.3017)
#
# Test set, Epoch 5 , Average loss: 2.2992, Accuracy: 512/10000 (5%)
#
# Epoch:  5
# Loss=  tensor(2.3011)
#
# Test set, Epoch 6 , Average loss: 2.3019, Accuracy: 497/10000 (5%)
#
# Epoch:  6
# Loss=  tensor(2.3003)
#
# Test set, Epoch 7 , Average loss: 2.3017, Accuracy: 883/10000 (9%)
#
# Epoch:  7
# Loss=  tensor(2.2995)
#
# Test set, Epoch 8 , Average loss: 2.3027, Accuracy: 388/10000 (4%)
#
# Epoch:  8
# Loss=  tensor(2.2983)
#
# Test set, Epoch 9 , Average loss: 2.3081, Accuracy: 531/10000 (5%)
#
# Epoch:  9
# Loss=  tensor(2.2971)
#
# Test set, Epoch 10 , Average loss: 2.3086, Accuracy: 688/10000 (7%)
#
# Epoch:  10
# Loss=  tensor(2.2955)
#
# Test set, Epoch 11 , Average loss: 2.3083, Accuracy: 639/10000 (6%)
#
# Epoch:  11
# Loss=  tensor(2.2940)
#
# Test set, Epoch 12 , Average loss: 2.2965, Accuracy: 904/10000 (9%)
#
# Epoch:  12
# Loss=  tensor(2.2918)
#
# Test set, Epoch 13 , Average loss: 2.3020, Accuracy: 858/10000 (9%)
#
# Epoch:  13
# Loss=  tensor(2.2900)
#
# Test set, Epoch 14 , Average loss: 2.3133, Accuracy: 815/10000 (8%)
#
# Epoch:  14
# Loss=  tensor(2.2877)
#
# Test set, Epoch 15 , Average loss: 2.3136, Accuracy: 865/10000 (9%)
#
# Epoch:  15
# Loss=  tensor(2.2852)
#
# Test set, Epoch 16 , Average loss: 2.3027, Accuracy: 1025/10000 (10%)
#
# Epoch:  16
# Loss=  tensor(2.2821)
#
# Test set, Epoch 17 , Average loss: 2.3083, Accuracy: 1065/10000 (11%)
#
# Epoch:  17
# Loss=  tensor(2.2797)
#
# Test set, Epoch 18 , Average loss: 2.3180, Accuracy: 1011/10000 (10%)
#
# Epoch:  18
# Loss=  tensor(2.2765)
#
# Test set, Epoch 19 , Average loss: 2.3028, Accuracy: 1150/10000 (12%)
#
# Epoch:  19
# Loss=  tensor(2.2740)
#
# Test set, Epoch 20 , Average loss: 2.3102, Accuracy: 1032/10000 (10%)
#
# Epoch:  20
# Loss=  tensor(2.2704)
#
# Test set, Epoch 21 , Average loss: 2.3092, Accuracy: 1117/10000 (11%)
#
# Epoch:  21
# Loss=  tensor(2.2672)
#
# Test set, Epoch 22 , Average loss: 2.3256, Accuracy: 944/10000 (9%)
#
# Epoch:  22
# Loss=  tensor(2.2635)
#
# Test set, Epoch 23 , Average loss: 2.3225, Accuracy: 989/10000 (10%)
#
# Epoch:  23
# Loss=  tensor(2.2594)
#
# Test set, Epoch 24 , Average loss: 2.3194, Accuracy: 1049/10000 (10%)
#
# Epoch:  24
# Loss=  tensor(2.2563)
#
# Test set, Epoch 25 , Average loss: 2.3209, Accuracy: 1106/10000 (11%)
#
# Epoch:  25
# Loss=  tensor(2.2523)
#
# Test set, Epoch 26 , Average loss: 2.3207, Accuracy: 925/10000 (9%)
#
# Epoch:  26
# Loss=  tensor(2.2481)
#
# Test set, Epoch 27 , Average loss: 2.3242, Accuracy: 1048/10000 (10%)
#
# Epoch:  27
# Loss=  tensor(2.2444)
#
# Test set, Epoch 28 , Average loss: 2.3234, Accuracy: 1041/10000 (10%)
#
# Epoch:  28
# Loss=  tensor(2.2411)
#
# Test set, Epoch 29 , Average loss: 2.3508, Accuracy: 978/10000 (10%)
#
# Epoch:  29
# Loss=  tensor(2.2365)
#
# Test set, Epoch 30 , Average loss: 2.3278, Accuracy: 1117/10000 (11%)
#
# Epoch:  30
# Loss=  tensor(2.2322)
#
# Test set, Epoch 31 , Average loss: 2.3438, Accuracy: 1010/10000 (10%)
#
# Epoch:  31
# Loss=  tensor(2.2285)
#
# Test set, Epoch 32 , Average loss: 2.3208, Accuracy: 1158/10000 (12%)
#
# Epoch:  32
# Loss=  tensor(2.2235)
#
# Test set, Epoch 33 , Average loss: 2.3561, Accuracy: 928/10000 (9%)
#
# Epoch:  33
# Loss=  tensor(2.2202)
#
# Test set, Epoch 34 , Average loss: 2.3585, Accuracy: 1050/10000 (10%)
#
# Epoch:  34
# Loss=  tensor(2.2157)
#
# Test set, Epoch 35 , Average loss: 2.3528, Accuracy: 1035/10000 (10%)
#
# Epoch:  35
# Loss=  tensor(2.2108)
#
# Test set, Epoch 36 , Average loss: 2.3432, Accuracy: 1101/10000 (11%)
#
# Epoch:  36
# Loss=  tensor(2.2069)
#
# Test set, Epoch 37 , Average loss: 2.3583, Accuracy: 1044/10000 (10%)
#
# Epoch:  37
# Loss=  tensor(2.2030)
#
# Test set, Epoch 38 , Average loss: 2.3683, Accuracy: 1131/10000 (11%)
#
# Epoch:  38
# Loss=  tensor(2.1989)
#
# Test set, Epoch 39 , Average loss: 2.3662, Accuracy: 1120/10000 (11%)
#
# Epoch:  39
# Loss=  tensor(2.1936)
#
# Test set, Epoch 40 , Average loss: 2.3744, Accuracy: 1044/10000 (10%)
#
# Epoch:  40
# Loss=  tensor(2.1897)
#
# Test set, Epoch 41 , Average loss: 2.3801, Accuracy: 1031/10000 (10%)
#
# Epoch:  41
# Loss=  tensor(2.1856)
#
# Test set, Epoch 42 , Average loss: 2.3953, Accuracy: 1058/10000 (11%)
#
# Epoch:  42
# Loss=  tensor(2.1809)
#
# Test set, Epoch 43 , Average loss: 2.3881, Accuracy: 1033/10000 (10%)
#
# Epoch:  43
# Loss=  tensor(2.1770)
#
# Test set, Epoch 44 , Average loss: 2.4030, Accuracy: 1027/10000 (10%)
#
# Epoch:  44
# Loss=  tensor(2.1731)
#
# Test set, Epoch 45 , Average loss: 2.3538, Accuracy: 1308/10000 (13%)
#
# Epoch:  45
# Loss=  tensor(2.1683)
#
# Test set, Epoch 46 , Average loss: 2.4054, Accuracy: 965/10000 (10%)
#
# Epoch:  46
# Loss=  tensor(2.1646)
#
# Test set, Epoch 47 , Average loss: 2.4117, Accuracy: 1017/10000 (10%)
#
# Epoch:  47
# Loss=  tensor(2.1593)
#
# Test set, Epoch 48 , Average loss: 2.4105, Accuracy: 1026/10000 (10%)
#
# Epoch:  48
# Loss=  tensor(2.1545)
#
# Test set, Epoch 49 , Average loss: 2.4270, Accuracy: 1011/10000 (10%)
#
# Epoch:  49
# Loss=  tensor(2.1513)
#
# Test set, Epoch 50 , Average loss: 2.4207, Accuracy: 990/10000 (10%)
#
# Epoch:  50
# Loss=  tensor(2.1465)
#
# Test set, Epoch 51 , Average loss: 2.4073, Accuracy: 1082/10000 (11%)
#
# Epoch:  51
# Loss=  tensor(2.1419)
#
# Test set, Epoch 52 , Average loss: 2.4114, Accuracy: 1054/10000 (11%)
#
# Epoch:  52
# Loss=  tensor(2.1388)
#
# Test set, Epoch 53 , Average loss: 2.4556, Accuracy: 917/10000 (9%)
#
# Epoch:  53
# Loss=  tensor(2.1325)
#
# Test set, Epoch 54 , Average loss: 2.4291, Accuracy: 1043/10000 (10%)
#
# Epoch:  54
# Loss=  tensor(2.1299)
#
# Test set, Epoch 55 , Average loss: 2.4126, Accuracy: 1129/10000 (11%)
#
# Epoch:  55
# Loss=  tensor(2.1244)
#
# Test set, Epoch 56 , Average loss: 2.4703, Accuracy: 940/10000 (9%)
#
# Epoch:  56
# Loss=  tensor(2.1203)
#
# Test set, Epoch 57 , Average loss: 2.4200, Accuracy: 1159/10000 (12%)
#
# Epoch:  57
# Loss=  tensor(2.1166)
#
# Test set, Epoch 58 , Average loss: 2.4755, Accuracy: 938/10000 (9%)
#
# Epoch:  58
# Loss=  tensor(2.1125)
#
# Test set, Epoch 59 , Average loss: 2.4425, Accuracy: 1097/10000 (11%)
#
# Epoch:  59
# Loss=  tensor(2.1083)
#
# Test set, Epoch 60 , Average loss: 2.4990, Accuracy: 896/10000 (9%)
#
# Epoch:  60
# Loss=  tensor(2.1042)
#
# Test set, Epoch 61 , Average loss: 2.4627, Accuracy: 1015/10000 (10%)
#
# Epoch:  61
# Loss=  tensor(2.0997)
#
# Test set, Epoch 62 , Average loss: 2.4575, Accuracy: 1065/10000 (11%)
#
# Epoch:  62
# Loss=  tensor(2.0956)
#
# Test set, Epoch 63 , Average loss: 2.4781, Accuracy: 1047/10000 (10%)
#
# Epoch:  63
# Loss=  tensor(2.0923)
#
# Test set, Epoch 64 , Average loss: 2.4558, Accuracy: 1072/10000 (11%)
#
# Epoch:  64
# Loss=  tensor(2.0878)
#
# Test set, Epoch 65 , Average loss: 2.4911, Accuracy: 957/10000 (10%)
#
# Epoch:  65
# Loss=  tensor(2.0840)
#
# Test set, Epoch 66 , Average loss: 2.5086, Accuracy: 929/10000 (9%)
#
# Epoch:  66
# Loss=  tensor(2.0798)
#
# Test set, Epoch 67 , Average loss: 2.4746, Accuracy: 1045/10000 (10%)
#
# Epoch:  67
# Loss=  tensor(2.0762)
#
# Test set, Epoch 68 , Average loss: 2.4967, Accuracy: 1001/10000 (10%)
#
# Epoch:  68
# Loss=  tensor(2.0719)
#
# Test set, Epoch 69 , Average loss: 2.4997, Accuracy: 989/10000 (10%)
#
# Epoch:  69
# Loss=  tensor(2.0674)
#
# Test set, Epoch 70 , Average loss: 2.4821, Accuracy: 1128/10000 (11%)
#
# Epoch:  70
# Loss=  tensor(2.0633)
#
# Test set, Epoch 71 , Average loss: 2.5115, Accuracy: 999/10000 (10%)
#
# Epoch:  71
# Loss=  tensor(2.0597)
#
# Test set, Epoch 72 , Average loss: 2.5106, Accuracy: 1016/10000 (10%)
#
# Epoch:  72
# Loss=  tensor(2.0561)
#
# Test set, Epoch 73 , Average loss: 2.5023, Accuracy: 1036/10000 (10%)
#
# Epoch:  73
# Loss=  tensor(2.0513)
#
# Test set, Epoch 74 , Average loss: 2.5088, Accuracy: 1039/10000 (10%)
#
# Epoch:  74
# Loss=  tensor(2.0484)
#
# Test set, Epoch 75 , Average loss: 2.5268, Accuracy: 1018/10000 (10%)
#
# Epoch:  75
# Loss=  tensor(2.0434)
#
# Test set, Epoch 76 , Average loss: 2.5584, Accuracy: 938/10000 (9%)
#
# Epoch:  76
# Loss=  tensor(2.0406)
#
# Test set, Epoch 77 , Average loss: 2.5449, Accuracy: 960/10000 (10%)
#
# Epoch:  77
# Loss=  tensor(2.0358)
#
# Test set, Epoch 78 , Average loss: 2.5432, Accuracy: 1003/10000 (10%)
#
# Epoch:  78
# Loss=  tensor(2.0327)
#
# Test set, Epoch 79 , Average loss: 2.5288, Accuracy: 1024/10000 (10%)
#
# Epoch:  79
# Loss=  tensor(2.0278)
#
# Test set, Epoch 80 , Average loss: 2.5436, Accuracy: 1008/10000 (10%)
#
# Epoch:  80
# Loss=  tensor(2.0247)
#
# Test set, Epoch 81 , Average loss: 2.5428, Accuracy: 1014/10000 (10%)
#
# Epoch:  81
# Loss=  tensor(2.0205)
#
# Test set, Epoch 82 , Average loss: 2.5890, Accuracy: 916/10000 (9%)
#
# Epoch:  82
# Loss=  tensor(2.0170)
#
# Test set, Epoch 83 , Average loss: 2.5758, Accuracy: 995/10000 (10%)
#
# Epoch:  83
# Loss=  tensor(2.0127)
#
# Test set, Epoch 84 , Average loss: 2.5477, Accuracy: 1038/10000 (10%)
#
# Epoch:  84
# Loss=  tensor(2.0094)
#
# Test set, Epoch 85 , Average loss: 2.5198, Accuracy: 1263/10000 (13%)
#
# Epoch:  85
# Loss=  tensor(2.0047)
#
# Test set, Epoch 86 , Average loss: 2.6184, Accuracy: 896/10000 (9%)
#
# Epoch:  86
# Loss=  tensor(2.0016)
#
# Test set, Epoch 87 , Average loss: 2.5425, Accuracy: 1163/10000 (12%)
#
# Epoch:  87
# Loss=  tensor(1.9979)
#
# Test set, Epoch 88 , Average loss: 2.5474, Accuracy: 1077/10000 (11%)
#
# Epoch:  88
# Loss=  tensor(1.9947)
#
# Test set, Epoch 89 , Average loss: 2.6196, Accuracy: 937/10000 (9%)
#
# Epoch:  89
# Loss=  tensor(1.9898)
#
# Test set, Epoch 90 , Average loss: 2.6066, Accuracy: 1100/10000 (11%)
#
# Epoch:  90
# Loss=  tensor(1.9868)
#
# Test set, Epoch 91 , Average loss: 2.6104, Accuracy: 964/10000 (10%)
#
# Epoch:  91
# Loss=  tensor(1.9829)
#
# Test set, Epoch 92 , Average loss: 2.5987, Accuracy: 952/10000 (10%)
#
# Epoch:  92
# Loss=  tensor(1.9792)
#
# Test set, Epoch 93 , Average loss: 2.6177, Accuracy: 1042/10000 (10%)
#
# Epoch:  93
# Loss=  tensor(1.9761)
#
# Test set, Epoch 94 , Average loss: 2.6415, Accuracy: 984/10000 (10%)
#
# Epoch:  94
# Loss=  tensor(1.9729)
#
# Test set, Epoch 95 , Average loss: 2.6175, Accuracy: 1028/10000 (10%)
#
# Epoch:  95
# Loss=  tensor(1.9694)
#
# Test set, Epoch 96 , Average loss: 2.6495, Accuracy: 996/10000 (10%)
#
# Epoch:  96
# Loss=  tensor(1.9656)
#
# Test set, Epoch 97 , Average loss: 2.5927, Accuracy: 1205/10000 (12%)
#
# Epoch:  97
# Loss=  tensor(1.9609)
#
# Test set, Epoch 98 , Average loss: 2.6155, Accuracy: 1031/10000 (10%)
#
# Epoch:  98
# Loss=  tensor(1.9591)
#
# Test set, Epoch 99 , Average loss: 2.6584, Accuracy: 1024/10000 (10%)
#
# Epoch:  99
# Loss=  tensor(1.9548)
#
# Test set, Epoch 100 , Average loss: 2.6662, Accuracy: 1053/10000 (11%)
#
# Epoch:  100
# Loss=  tensor(1.9516)

# %%
temp_1 = []
for i in m1_train_loss_arr:
    temp_1.append(i.data.numpy().tolist())
temp_2 = []
for i in m1_test_loss_arr:
    temp_2.append(i.data.numpy().tolist())

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 100, 1), temp_1, color = "r")
plt.plot(np.arange(0, 100, 1), temp_2, color = "g")
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
